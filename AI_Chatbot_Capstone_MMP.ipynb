# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
data_root='/content/drive/My Drive/ChatBot'
# Out:
# Mounted at /content/drive

# %%
# Importing relevant libraries
import json
import string
import random
import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout

nltk.download("punkt")
nltk.download("wordnet")

#Loading the dataset: intents.json

data_file = open(data_root + '/intents.json').read()
data = json.loads(data_file)

# Creating data_x and Data_Y
words = []  # for model/ vocabulary for patterns
classes = []  # for bow model/ vocabulary for tags
data_X = []  # for storing each pattern
data_Y = []  # for storing tags corresponding to each pattern in data_x

# Iterating over all the intents
for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens = nltk.word_tokenize(pattern)  # tokenize each pattern
        words.extend(tokens)  # and append tokens to words
        data_X.append(pattern)  # appending pattern to data_X
        data_Y.append(intent["tag"])  # appending the associated tag to each pattern

        # Adding the tag to the classes if it's not there already
        if intent["tag"] not in classes:
            classes.append(intent["tag"])

# Initializing lemmatizer to get stem of words
lemmatizer = WordNetLemmatizer()

# Lemmatize all the words in the vocab and convert them to lowercase
# if the words don't appear in punctuation
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]

# Sorting the vocab and classes in alphabetical order and taking the set to ensure no duplicates occur
words = sorted(set(words))
classes = sorted(set(classes))

# Text to numbers
training = []
out_empty = [0] * len(classes)

# Creating the bag of words model
for idx, doc in enumerate(data_X):
    bow = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)

    # Mark the index of class that the current pattern is associated with
    output_row = list(out_empty)
    output_row[classes.index(data_Y[idx])] = 1

    # Add the one hot encoded BoW and associated classes to training
    training.append([bow, output_row])

# Shuffle the data and convert it to an array
random.shuffle(training)
training = np.array(training, dtype=object)

# Split the features and target labels
train_X = np.array(list(training[:, 0]))
train_Y = np.array(list(training[:, 1]))

# The neural network model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_X[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_Y[0]), activation="softmax"))
adam = tf.keras.optimizers.legacy.Adam(learning_rate=0.01, decay=1e-6)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=["accuracy"])
print(model.summary())
model.fit(x=train_X, y=train_Y, epochs=150, verbose=1)

# Preprocessing the inputs
def clean_text(text):
    tokens = nltk.word_tokenize(text)
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    return tokens

def bag_of_words(text, vocab):
    tokens = clean_text(text)
    bow = [0] * len(vocab)
    for w in tokens:
        for idx, word in enumerate(vocab):
            if word == w:  # Corrected comparison
                bow[idx] = 1
    return np.array(bow)

def pred_class(text, vocab, labels):
    bow = bag_of_words(text, vocab)
    result = model.predict(np.array([bow]))[0]
    thresh = 0.5
    y_pred = [[indx, res] for indx, res in enumerate(result) if res > thresh]
    y_pred.sort(key=lambda x: x[1], reverse=True)  # Sorting by values of probability in decreasing order
    return_list = []
    for r in y_pred:
        return_list.append(labels[r[0]])
    return return_list

def get_response(intents_list, intents_json):
    if len(intents_list) == 0:
        result = random.choice(intents_json["intents"][1]["responses"])  # Default response for no matching intent
    else:
        tag = intents_list[0]
        list_of_intents = intents_json["intents"]
        for i in list_of_intents:
            if i["tag"] == tag:
                result = random.choice(i["responses"])
                break
    return result
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 128)               7552
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 15)                975
#
# =================================================================
# Total params: 16783 (65.56 KB)
# Trainable params: 16783 (65.56 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# None
# Epoch 1/150
# 2/2 [==============================] - 1s 19ms/step - loss: 2.7045 - accuracy: 0.0000e+00
# Epoch 2/150
# 2/2 [==============================] - 0s 17ms/step - loss: 2.6376 - accuracy: 0.2195
# Epoch 3/150
# 2/2 [==============================] - 0s 17ms/step - loss: 2.4185 - accuracy: 0.2195
# Epoch 4/150
# 2/2 [==============================] - 0s 11ms/step - loss: 2.2037 - accuracy: 0.4390
# Epoch 5/150
# 2/2 [==============================] - 0s 12ms/step - loss: 2.1778 - accuracy: 0.4390
# Epoch 6/150
# 2/2 [==============================] - 0s 12ms/step - loss: 1.9003 - accuracy: 0.4390
# Epoch 7/150
# 2/2 [==============================] - 0s 12ms/step - loss: 1.8736 - accuracy: 0.4878
# Epoch 8/150
# 2/2 [==============================] - 0s 12ms/step - loss: 1.6717 - accuracy: 0.4878
# Epoch 9/150
# 2/2 [==============================] - 0s 11ms/step - loss: 1.5427 - accuracy: 0.4634
# Epoch 10/150
# 2/2 [==============================] - 0s 11ms/step - loss: 1.6205 - accuracy: 0.5366
# Epoch 11/150
# 2/2 [==============================] - 0s 12ms/step - loss: 1.4602 - accuracy: 0.5854
# Epoch 12/150
# 2/2 [==============================] - 0s 13ms/step - loss: 1.0171 - accuracy: 0.6829
# Epoch 13/150
# 2/2 [==============================] - 0s 12ms/step - loss: 1.2473 - accuracy: 0.6341
# Epoch 14/150
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0053 - accuracy: 0.6585
# Epoch 15/150
# 2/2 [==============================] - 0s 14ms/step - loss: 1.1169 - accuracy: 0.6341
# Epoch 16/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.8407 - accuracy: 0.7317
# Epoch 17/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.8555 - accuracy: 0.7317
# Epoch 18/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.9783 - accuracy: 0.7073
# Epoch 19/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.8143 - accuracy: 0.7073
# Epoch 20/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.6062 - accuracy: 0.7805
# Epoch 21/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.6167 - accuracy: 0.7561
# Epoch 22/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5176 - accuracy: 0.8293
# Epoch 23/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6834 - accuracy: 0.7805
# Epoch 24/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5734 - accuracy: 0.7805
# Epoch 25/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2918 - accuracy: 0.9512
# Epoch 26/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5359 - accuracy: 0.8293
# Epoch 27/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3414 - accuracy: 0.9024
# Epoch 28/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.4677 - accuracy: 0.8049
# Epoch 29/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3693 - accuracy: 0.8780
# Epoch 30/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.3219 - accuracy: 0.9024
# Epoch 31/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2681 - accuracy: 0.9024
# Epoch 32/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3226 - accuracy: 0.8537
# Epoch 33/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2755 - accuracy: 0.9024
# Epoch 34/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3269 - accuracy: 0.8537
# Epoch 35/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2233 - accuracy: 0.9512
# Epoch 36/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3557 - accuracy: 0.8780
# Epoch 37/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2135 - accuracy: 0.9268
# Epoch 38/150
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2090 - accuracy: 0.9268
# Epoch 39/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2821 - accuracy: 0.9268
# Epoch 40/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2927 - accuracy: 0.9024
# Epoch 41/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3610 - accuracy: 0.8780
# Epoch 42/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2095 - accuracy: 0.9756
# Epoch 43/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2017 - accuracy: 0.9268
# Epoch 44/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2937 - accuracy: 0.9512
# Epoch 45/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1672 - accuracy: 0.9756
# Epoch 46/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1499 - accuracy: 0.9512
# Epoch 47/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0952 - accuracy: 1.0000
# Epoch 48/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1147 - accuracy: 0.9512
# Epoch 49/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2819 - accuracy: 0.9268
# Epoch 50/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1056 - accuracy: 1.0000
# Epoch 51/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1308 - accuracy: 0.9756
# Epoch 52/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2489 - accuracy: 0.9024
# Epoch 53/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1079 - accuracy: 0.9756
# Epoch 54/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0721 - accuracy: 1.0000
# Epoch 55/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2363 - accuracy: 0.9024
# Epoch 56/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2799 - accuracy: 0.9024
# Epoch 57/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0534 - accuracy: 1.0000
# Epoch 58/150
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1328 - accuracy: 0.9512
# Epoch 59/150
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1805 - accuracy: 0.9268
# Epoch 60/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.3390 - accuracy: 0.9268
# Epoch 61/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2225 - accuracy: 0.8780
# Epoch 62/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2823 - accuracy: 0.9756
# Epoch 63/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1229 - accuracy: 0.9268
# Epoch 64/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2402 - accuracy: 0.9268
# Epoch 65/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1277 - accuracy: 0.9512
# Epoch 66/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1114 - accuracy: 0.9756
# Epoch 67/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2085 - accuracy: 0.9268
# Epoch 68/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1070 - accuracy: 0.9756
# Epoch 69/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1132 - accuracy: 0.9756
# Epoch 70/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1404 - accuracy: 0.9268
# Epoch 71/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0565 - accuracy: 1.0000
# Epoch 72/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0751 - accuracy: 0.9756
# Epoch 73/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2439 - accuracy: 0.9512
# Epoch 74/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1766 - accuracy: 0.9512
# Epoch 75/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3158 - accuracy: 0.8537
# Epoch 76/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2312 - accuracy: 0.9268
# Epoch 77/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1021 - accuracy: 0.9756
# Epoch 78/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1463 - accuracy: 0.9268
# Epoch 79/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1207 - accuracy: 0.9512
# Epoch 80/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2338 - accuracy: 0.9268
# Epoch 81/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0803 - accuracy: 0.9512
# Epoch 82/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1843 - accuracy: 0.9512
# Epoch 83/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3851 - accuracy: 0.8537
# Epoch 84/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1700 - accuracy: 0.9268
# Epoch 85/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0868 - accuracy: 0.9756
# Epoch 86/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2783 - accuracy: 0.9512
# Epoch 87/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2434 - accuracy: 0.9268
# Epoch 88/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1433 - accuracy: 0.9756
# Epoch 89/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0579 - accuracy: 1.0000
# Epoch 90/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2346 - accuracy: 0.9512
# Epoch 91/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0999 - accuracy: 0.9756
# Epoch 92/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2254 - accuracy: 0.9024
# Epoch 93/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1323 - accuracy: 0.9512
# Epoch 94/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1492 - accuracy: 0.9268
# Epoch 95/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1284 - accuracy: 0.9512
# Epoch 96/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0742 - accuracy: 0.9756
# Epoch 97/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1263 - accuracy: 0.9756
# Epoch 98/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1899 - accuracy: 0.9268
# Epoch 99/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1373 - accuracy: 0.9512
# Epoch 100/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2079 - accuracy: 0.9268
# Epoch 101/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1140 - accuracy: 0.9512
# Epoch 102/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1192 - accuracy: 0.9756
# Epoch 103/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1285 - accuracy: 0.9512
# Epoch 104/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1479 - accuracy: 0.9268
# Epoch 105/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1049 - accuracy: 0.9756
# Epoch 106/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1387 - accuracy: 0.9512
# Epoch 107/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1480 - accuracy: 0.9756
# Epoch 108/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1441 - accuracy: 0.9268
# Epoch 109/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0733 - accuracy: 1.0000
# Epoch 110/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0627 - accuracy: 1.0000
# Epoch 111/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0644 - accuracy: 0.9756
# Epoch 112/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0674 - accuracy: 0.9512
# Epoch 113/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1795 - accuracy: 0.9268
# Epoch 114/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0514 - accuracy: 1.0000
# Epoch 115/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0948 - accuracy: 0.9756
# Epoch 116/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0720 - accuracy: 1.0000
# Epoch 117/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1853 - accuracy: 0.9512
# Epoch 118/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1841 - accuracy: 0.9512
# Epoch 119/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2551 - accuracy: 0.8780
# Epoch 120/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0930 - accuracy: 0.9756
# Epoch 121/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1613 - accuracy: 0.9512
# Epoch 122/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1538 - accuracy: 0.9756
# Epoch 123/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0648 - accuracy: 1.0000
# Epoch 124/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1027 - accuracy: 0.9756
# Epoch 125/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1625 - accuracy: 0.9268
# Epoch 126/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1684 - accuracy: 0.9512
# Epoch 127/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0883 - accuracy: 0.9512
# Epoch 128/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3100 - accuracy: 0.8780
# Epoch 129/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0725 - accuracy: 0.9756
# Epoch 130/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1325 - accuracy: 0.9512
# Epoch 131/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0719 - accuracy: 0.9756
# Epoch 132/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0567 - accuracy: 0.9756
# Epoch 133/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1174 - accuracy: 0.9268
# Epoch 134/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1298 - accuracy: 0.9512
# Epoch 135/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1616 - accuracy: 0.9024
# Epoch 136/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0359 - accuracy: 1.0000
# Epoch 137/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2427 - accuracy: 0.9024
# Epoch 138/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0557 - accuracy: 0.9756
# Epoch 139/150
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1413 - accuracy: 0.9512
# Epoch 140/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2455 - accuracy: 0.9512
# Epoch 141/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0354 - accuracy: 1.0000
# Epoch 142/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1715 - accuracy: 0.9268
# Epoch 143/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1966 - accuracy: 0.9512
# Epoch 144/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0873 - accuracy: 0.9512
# Epoch 145/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0814 - accuracy: 0.9756
# Epoch 146/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0834 - accuracy: 0.9512
# Epoch 147/150
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 148/150
# 2/2 [==============================] - 0s 20ms/step - loss: 0.1371 - accuracy: 0.9268
# Epoch 149/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0602 - accuracy: 0.9756
# Epoch 150/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1030 - accuracy: 0.9512

# %%
# Interacting with the chatbot
print("Type '0' if you don't want to chat with our ChatBot.")
while True:
    message = input("")
    if message == "0":
        break
    intents = pred_class(message, words, classes)
    result = get_response(intents, data)
    print(result)
# Out:
# Type '0' if you don't want to chat with our ChatBot.
# hey
# 1/1 [==============================] - 0s 109ms/step
# So, everything's okay!
# how are you
# 1/1 [==============================] - 0s 24ms/step
# Very good and you?
# i am good
# 1/1 [==============================] - 0s 24ms/step
# So, everything's okay!
# what do you do
# 1/1 [==============================] - 0s 23ms/step
# Actually, I'm chatting with somebody
# where do you live
# 1/1 [==============================] - 0s 32ms/step
# I live in a server located in the US!
