# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
data_root='/content/drive/My Drive/ChatBot'
# Out:
# Mounted at /content/drive

# %%
# Importing relevant libraries
import json
import string
import random
import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout

nltk.download("punkt")
nltk.download("wordnet")

#Loading the dataset: intents.json

data_file = open(data_root + '/intents.json').read()
data = json.loads(data_file)

# Creating data_x and Data_Y
words = []  # for model/ vocabulary for patterns
classes = []  # for bow model/ vocabulary for tags
data_X = []  # for storing each pattern
data_Y = []  # for storing tags corresponding to each pattern in data_x

# Iterating over all the intents
for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens = nltk.word_tokenize(pattern)  # tokenize each pattern
        words.extend(tokens)  # and append tokens to words
        data_X.append(pattern)  # appending pattern to data_X
        data_Y.append(intent["tag"])  # appending the associated tag to each pattern

        # Adding the tag to the classes if it's not there already
        if intent["tag"] not in classes:
            classes.append(intent["tag"])

# Initializing lemmatizer to get stem of words
lemmatizer = WordNetLemmatizer()

# Lemmatize all the words in the vocab and convert them to lowercase
# if the words don't appear in punctuation
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]

# Sorting the vocab and classes in alphabetical order and taking the set to ensure no duplicates occur
words = sorted(set(words))
classes = sorted(set(classes))

# Text to numbers
training = []
out_empty = [0] * len(classes)

# Creating the bag of words model
for idx, doc in enumerate(data_X):
    bow = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)

    # Mark the index of class that the current pattern is associated with
    output_row = list(out_empty)
    output_row[classes.index(data_Y[idx])] = 1

    # Add the one hot encoded BoW and associated classes to training
    training.append([bow, output_row])

# Shuffle the data and convert it to an array
random.shuffle(training)
training = np.array(training, dtype=object)

# Split the features and target labels
train_X = np.array(list(training[:, 0]))
train_Y = np.array(list(training[:, 1]))

# The neural network model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_X[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_Y[0]), activation="softmax"))
adam = tf.keras.optimizers.legacy.Adam(learning_rate=0.01, decay=1e-6)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=["accuracy"])
print(model.summary())
model.fit(x=train_X, y=train_Y, epochs=150, verbose=1)

# Preprocessing the inputs
def clean_text(text):
    tokens = nltk.word_tokenize(text)
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    return tokens

def bag_of_words(text, vocab):
    tokens = clean_text(text)
    bow = [0] * len(vocab)
    for w in tokens:
        for idx, word in enumerate(vocab):
            if word == w:  # Corrected comparison
                bow[idx] = 1
    return np.array(bow)

def pred_class(text, vocab, labels):
    bow = bag_of_words(text, vocab)
    result = model.predict(np.array([bow]))[0]
    thresh = 0.5
    y_pred = [[indx, res] for indx, res in enumerate(result) if res > thresh]
    y_pred.sort(key=lambda x: x[1], reverse=True)  # Sorting by values of probability in decreasing order
    return_list = []
    for r in y_pred:
        return_list.append(labels[r[0]])
    return return_list

def get_response(intents_list, intents_json):
    if len(intents_list) == 0:
        result = random.choice(intents_json["intents"][1]["responses"])  # Default response for no matching intent
    else:
        tag = intents_list[0]
        list_of_intents = intents_json["intents"]
        for i in list_of_intents:
            if i["tag"] == tag:
                result = random.choice(i["responses"])
                break
    return result
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 128)               6784
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 11)                715
#
# =================================================================
# Total params: 15755 (61.54 KB)
# Trainable params: 15755 (61.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/150
# 2/2 [==============================] - 1s 13ms/step - loss: 2.4443 - accuracy: 0.1143
# Epoch 2/150
# 2/2 [==============================] - 0s 15ms/step - loss: 2.3402 - accuracy: 0.1714
# Epoch 3/150
# 2/2 [==============================] - 0s 15ms/step - loss: 2.2875 - accuracy: 0.1429
# Epoch 4/150
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0803 - accuracy: 0.3714
# Epoch 5/150
# 2/2 [==============================] - 0s 20ms/step - loss: 1.9885 - accuracy: 0.4000
# Epoch 6/150
# 2/2 [==============================] - 0s 18ms/step - loss: 2.0141 - accuracy: 0.4857
# Epoch 7/150
# 2/2 [==============================] - 0s 14ms/step - loss: 1.8267 - accuracy: 0.5429
# Epoch 8/150
# 2/2 [==============================] - 0s 22ms/step - loss: 1.5510 - accuracy: 0.6571
# Epoch 9/150
# 2/2 [==============================] - 0s 13ms/step - loss: 1.4655 - accuracy: 0.7429
# Epoch 10/150
# 2/2 [==============================] - 0s 14ms/step - loss: 1.4225 - accuracy: 0.5429
# Epoch 11/150
# 2/2 [==============================] - 0s 20ms/step - loss: 1.3252 - accuracy: 0.6571
# Epoch 12/150
# 2/2 [==============================] - 0s 17ms/step - loss: 1.2077 - accuracy: 0.7143
# Epoch 13/150
# 2/2 [==============================] - 0s 21ms/step - loss: 1.0409 - accuracy: 0.6857
# Epoch 14/150
# 2/2 [==============================] - 0s 20ms/step - loss: 0.8083 - accuracy: 0.8857
# Epoch 15/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.7009 - accuracy: 0.8286
# Epoch 16/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6600 - accuracy: 0.8571
# Epoch 17/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4360 - accuracy: 0.8857
# Epoch 18/150
# 2/2 [==============================] - 0s 22ms/step - loss: 0.5800 - accuracy: 0.8000
# Epoch 19/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.3978 - accuracy: 0.9143
# Epoch 20/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3429 - accuracy: 0.8857
# Epoch 21/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6005 - accuracy: 0.8000
# Epoch 22/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2313 - accuracy: 0.9429
# Epoch 23/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2813 - accuracy: 0.8857
# Epoch 24/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.4321 - accuracy: 0.8571
# Epoch 25/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3023 - accuracy: 0.9429
# Epoch 26/150
# 2/2 [==============================] - 0s 19ms/step - loss: 0.2292 - accuracy: 0.9143
# Epoch 27/150
# 2/2 [==============================] - 0s 18ms/step - loss: 0.5004 - accuracy: 0.8286
# Epoch 28/150
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2210 - accuracy: 0.9429
# Epoch 29/150
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2373 - accuracy: 0.9143
# Epoch 30/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1459 - accuracy: 0.9143
# Epoch 31/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2459 - accuracy: 0.9143
# Epoch 32/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1260 - accuracy: 0.9714
# Epoch 33/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1017 - accuracy: 0.9714
# Epoch 34/150
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1522 - accuracy: 0.9714
# Epoch 35/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3469 - accuracy: 0.9429
# Epoch 36/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2600 - accuracy: 0.9143
# Epoch 37/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0924 - accuracy: 1.0000
# Epoch 38/150
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2525 - accuracy: 0.9143
# Epoch 39/150
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1594 - accuracy: 0.9143
# Epoch 40/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0455 - accuracy: 1.0000
# Epoch 41/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1413 - accuracy: 0.9714
# Epoch 42/150
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 43/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1449 - accuracy: 0.9714
# Epoch 44/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0806 - accuracy: 0.9714
# Epoch 45/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0740 - accuracy: 0.9714
# Epoch 46/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1403 - accuracy: 0.9429
# Epoch 47/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0619 - accuracy: 1.0000
# Epoch 48/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0436 - accuracy: 1.0000
# Epoch 49/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0474 - accuracy: 1.0000
# Epoch 50/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0855 - accuracy: 0.9714
# Epoch 51/150
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1238 - accuracy: 0.9429
# Epoch 52/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 53/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 54/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 55/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 56/150
# 2/2 [==============================] - 0s 20ms/step - loss: 0.1299 - accuracy: 0.9429
# Epoch 57/150
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 58/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0773 - accuracy: 0.9714
# Epoch 59/150
# 2/2 [==============================] - 0s 20ms/step - loss: 0.1252 - accuracy: 0.9714
# Epoch 60/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0983 - accuracy: 0.9714
# Epoch 61/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0613 - accuracy: 0.9714
# Epoch 62/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1279 - accuracy: 0.9714
# Epoch 63/150
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1100 - accuracy: 0.9714
# Epoch 64/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 65/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 66/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0571 - accuracy: 1.0000
# Epoch 67/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0433 - accuracy: 1.0000
# Epoch 68/150
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0617 - accuracy: 1.0000
# Epoch 69/150
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 70/150
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1092 - accuracy: 0.9714
# Epoch 71/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 72/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0926 - accuracy: 0.9714
# Epoch 73/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0441 - accuracy: 1.0000
# Epoch 74/150
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1315 - accuracy: 0.9429
# Epoch 75/150
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1513 - accuracy: 0.9429
# Epoch 76/150
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0386 - accuracy: 1.0000
# Epoch 77/150
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1386 - accuracy: 0.9429
# Epoch 78/150
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0835 - accuracy: 0.9714
# Epoch 79/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 80/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1769 - accuracy: 0.9143
# Epoch 81/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1029 - accuracy: 0.9714
# Epoch 82/150
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 83/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 84/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 85/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 86/150
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 87/150
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0990 - accuracy: 0.9714
# Epoch 88/150
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 89/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0846 - accuracy: 0.9714
# Epoch 90/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 91/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 92/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 93/150
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 94/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 95/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1199 - accuracy: 0.9429
# Epoch 96/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 97/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 98/150
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1509 - accuracy: 0.9429
# Epoch 99/150
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0737 - accuracy: 0.9714
# Epoch 100/150
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 101/150
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0769 - accuracy: 0.9714
# Epoch 102/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 103/150
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 104/150
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0727 - accuracy: 0.9714
# Epoch 105/150
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1517 - accuracy: 0.9714
# Epoch 106/150
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0850 - accuracy: 0.9714
# Epoch 107/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0801 - accuracy: 0.9429
# Epoch 108/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1432 - accuracy: 0.9429
# Epoch 109/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 110/150
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0555 - accuracy: 0.9714
# Epoch 111/150
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 112/150
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 113/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0457 - accuracy: 1.0000
# Epoch 114/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 115/150
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 116/150
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0694 - accuracy: 0.9714
# Epoch 117/150
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0445 - accuracy: 0.9714
# Epoch 118/150
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0564 - accuracy: 1.0000
# Epoch 119/150
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 120/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 121/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0776 - accuracy: 0.9429
# Epoch 122/150
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1311 - accuracy: 0.9143
# Epoch 123/150
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 124/150
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 125/150
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 126/150
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 127/150
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 128/150
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0262 - accuracy: 1.0000
# Epoch 129/150
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 130/150
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0393 - accuracy: 0.9714
# Epoch 131/150
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1480 - accuracy: 0.9714
# Epoch 132/150
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0485 - accuracy: 1.0000
# Epoch 133/150
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 134/150
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0528 - accuracy: 1.0000
# Epoch 135/150
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 136/150
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0787 - accuracy: 0.9714
# Epoch 137/150
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0890 - accuracy: 0.9429
# Epoch 138/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0725 - accuracy: 0.9714
# Epoch 139/150
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 140/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1232 - accuracy: 0.9714
# Epoch 141/150
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0623 - accuracy: 0.9714
# Epoch 142/150
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 143/150
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0323 - accuracy: 1.0000
# Epoch 144/150
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1108 - accuracy: 0.9714
# Epoch 145/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 146/150
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 147/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0383 - accuracy: 0.9714
# Epoch 148/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 149/150
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 150/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0016 - accuracy: 1.0000

# %%
# Interacting with the chatbot
print("Type '0' if you don't want to chat with our ChatBot.")
while True:
    message = input("")
    if message == "0":
        break
    intents = pred_class(message, words, classes)
    result = get_response(intents, data)
    print(result)
# Out:
# Type '0' if you don't want to chat with our ChatBot.
# hey
# 1/1 [==============================] - 0s 31ms/step
# Hello! How can I assist you today?
# apply for loan
# 1/1 [==============================] - 0s 22ms/step
# Interested in a loan? Let's discuss your options.
# file a complaint
# 1/1 [==============================] - 0s 21ms/step
# I'm sorry to hear that. Please provide details about your complaint, and I'll escalate it to our support team.
# show recent transactions
# 1/1 [==============================] - 0s 22ms/step
# Sure! I can provide you with your recent transaction history.
